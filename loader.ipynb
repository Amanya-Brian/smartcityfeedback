# %%
from langchain_community.document_loaders import JSONLoader
import jsonlines, json
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
# loader = JSONLoader("test.jsonl", jq_schema = ".title, .content")

# text = loader.load()

# print(text)

# Open and read the JSONL file
with jsonlines.open('rwanda.jsonl') as reader:
    documents = [obj for obj in reader]

# documents
docs = []

# initialize text splitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=300,chunk_overlap=30)
for doc in documents:
    split = text_splitter.split_text(doc["content"])
    single_doc = text_splitter.create_documents(texts=split)
    docs.append(single_doc)

print(docs)
# Out:
# [[Document(metadata={}, page_content='Investment Opportunities Manufacturing The manufacturing sector in Rwanda is still small but steadily growing at an annual rate of 7. Rwanda targets to increase industrial contribution to GDP to 26 by 2020. several policies and strategies such as the National Industrial Policy and the National'), Document(metadata={}, page_content='Policy and the National Export strategy have been developed to accelerate industrial and export growth The country has also put in place a National Industrial Policy which aims at diversifying the economy by increasing the share of industry to the countrys GDP, increase exports to 1.5 billion UsD'), Document(metadata={}, page_content='exports to 1.5 billion UsD by 2020 and increase the number of off-farm jobs. Market access Rwandas strategic location has boosted cross border trade and increased trade volumes with her neighbors especially East-Central Africa with an estimated population of 268 million Key products expor
# ...

# %%
print(docs[0])
print(docs[1])
# Out:
# [Document(metadata={}, page_content='Investment Opportunities Manufacturing The manufacturing sector in Rwanda is still small but steadily growing at an annual rate of 7. Rwanda targets to increase industrial contribution to GDP to 26 by 2020. several policies and strategies such as the National Industrial Policy and the National'), Document(metadata={}, page_content='Policy and the National Export strategy have been developed to accelerate industrial and export growth The country has also put in place a National Industrial Policy which aims at diversifying the economy by increasing the share of industry to the countrys GDP, increase exports to 1.5 billion UsD'), Document(metadata={}, page_content='exports to 1.5 billion UsD by 2020 and increase the number of off-farm jobs. Market access Rwandas strategic location has boosted cross border trade and increased trade volumes with her neighbors especially East-Central Africa with an estimated population of 268 million Key products export
# ...
